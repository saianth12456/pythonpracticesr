# %% [markdown]
# <a href="https://colab.research.google.com/github/saianth12456/pythonpracticesr/blob/p1/prime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fn_prime(ele):
  if ele>1:
    for i in range(2,ele):
      if ele%i==0:
        print(ele,"is not prime")
        break
    else:
     print(ele,"is prime")
  else:
    print(ele,"is not prime")

# %%
fn_prime(ele=7)
fn_prime(ele=27)
# Out:
# 7 is prime
# 27 is not prime

# %%
a=[2,5,7,25,32]
for ele in a:
  fn_prime(ele)
# Out:
# 2 is prime
# 5 is prime
# 7 is prime
# 25 is not prime
# 32 is not prime

# %%
def fn_prime_range(start,end):
  for ele in range(start,end+1):
    if ele>1:
      for i in range(2,ele):
        if ele%i==0:
          print(ele,"is not prime")
          break
      else:
        print(ele,"is prime")
    else:
      print(ele,"is not prime")

# %%
fn_prime_range(10,20)
# Out:
# 10 is not prime
# 11 is prime
# 12 is not prime
# 13 is prime
# 14 is not prime
# 15 is not prime
# 16 is not prime
# 17 is prime
# 18 is not prime
# 19 is prime
# 20 is not prime
